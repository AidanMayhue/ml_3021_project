# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np

# %%
# Education
edu = pd.read_csv("../data/un_data/Education.csv")
edu = edu[edu["Country/Region Name"] != "Total, all countries or areas"]
edu.head()
# Out:
#     Region/Country/Area Country/Region Name  Year  \
# 36                   15     Northern Africa  2005
# 37                   15     Northern Africa  2005
# 38                   15     Northern Africa  2005
# 39                   15     Northern Africa  2005
# 40                   15     Northern Africa  2005
#
#                                                Series   Value
# 36  Students enrolled in primary education (thousa...  23,023
# 37            Gross enrollment ratio - Primary (male)    95.7
# 38          Gross enrollment ratio - Primary (female)    89.3
# 39  Students enrolled in lower secondary education...  10,029
# 40  Gross enrollment ratio - Lower secondary level...    86.8

# %%
edu_pivot = edu.pivot_table(index = "Country/Region Name", columns = "Series", values = "Value", aggfunc = "first")
edu_pivot.head()
# Out:
# Series              Gross enrollment ratio - Lower secondary level (female)  \
# Country/Region Name
# Afghanistan                                                       13.4
# Albania                                                            101
# Algeria                                                          109.4
# Andorra                                                           99.9
# Angola                                                            18.2
#
# Series              Gross enrollment ratio - Lower secondary level (male)  \
# Country/Region Name
# Afghanistan                                                       39.5
# Albania                                                          105.4
# Algeria                                                          113.9
# Andorra                                                           93.2
# Angola                                                              21
#
# ...

# %%
# Gender Equality (Gov or Both)
# Labor and Unemployment
# Crime
# Water and Sanitation
# GDP
# Population
